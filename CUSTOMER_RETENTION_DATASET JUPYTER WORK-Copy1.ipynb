# %%
#importing warning libraries to avaoid  any warnings
import warnings
warnings.filterwarnings('ignore')
print('success')
# Out:
# success

# %% [markdown]
# # LOADING DATASET

# %%
import pandas as pd
df= pd.read_excel('D:\customer_retention_dataset1.xlsx')  #r'C:\Users\Ron\Desktop\Product List.xlsx'
df.head(5)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail(5)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# # DATASET DESCRIPTION

# %% [markdown]
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers¶
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
#
# -> There are totally 269 rows and 71 columns in this dataset
#
# -> Our objective is to find the insights of the data and to do thorough data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# There are 70 columns object type and one column int

# %%
df.isnull().sum()   # checking the null values in the dataset
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#checking the null values of each column separately
for i in df.columns:
    print(i)
    print(df[i].isnull().sum())
# Out:
# 1Gender of respondent
# 0
# 2 How old are you?
# 0
# 3 Which city do you shop online from?
# 0
# 4 What is the Pin Code of where you shop online from?
# 0
# 5 Since How Long You are Shopping Online ?
# 0
# 6 How many times you have made an online purchase in the past 1 year?
# 0
# 7 How do you access the internet while shopping on-line?
# 0
# 8 Which device do you use to access the online shopping?
# 0
# 9 What is the screen size of your mobile device?
# 0
# 10 What is the operating system (OS) of your device?
# 0
# 11 What browser do you run on your device to access the website?
# 0
# 12 Which channel did you follow to arrive at your favorite online store for the first time?
# 0
# 13 After first visit, how do you reach the online retail store?
# 0
# 14 How much time do you explore the e- retail store before making a purchase decision?
# 0
# 15 What is your preferred payment Option?
# 0
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#importing matplotlib and seaborn libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#checking all value counts in all features in the dataset
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print('\n')
# Out:
# 1Gender of respondent
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
#
#
# 2 How old are you?
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
#
#
# 3 Which city do you shop online from?
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
#
#
# 4 What is the Pin Code of where you shop online from?
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# ...

# %%
#plotting countplot for all the columns present
for i in df.columns:
    plt.figure(i)
    print(sns.countplot(df[i]))
    plt.xticks(rotation=90)      #heading font style
    print('\n')
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)
#
#
# ...

# %% [markdown]
# Observations
#
# 1.Above 41-50 years and less than 20 years, female and male respondents count difference is not much.
#
# 2.From Bangalore and Greater Noida, many respondents are female.
#
# 3.From Noida and Delhi, many respondents are male.
#
# 4.Both men and women shopping from desktop count are almost same. However, more women shop from either smartphone or laptop.
#
# 5.Most of the women come back to shopping website by using search engine.
#
# 6.Many women prefer to use search engine or app, rather than direct URL. However, men prefer to use search engine and Url and app little less. So we can understand that women use app more than men.
#
# 7.Women spend more time than men during online shopping and the time is mostly more than 15 mins, followed by 11-15 mins.
#
# 8.Women too compare the products with other websites and is one of the reasons to leave the cart without shopping.
#
# 9.Women prefer more loyalpoints than men.
#
# 10.More women disagree that online shopping is a kind of adventure. So websites need to work towards giving real time experience as this can be a big marketing strategy.
#
# 11.Women dont feel that online shopping fulfills certain roles.
#
# 12.Rest of all other observations are similar as observed in the before countplots.

# %% [markdown]
# # Analysis of website feedbacks obtained

# %% [markdown]
# We can see that after column 47, there are both positive and negative feedbacks of the websites, which are given by the correspondents. We will analyse those data by using data analysis process

# %%
#Extracting the datas from where feedback is starting
df_feedback = df.iloc[:,47:]
df_feedback
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
#A separate dataframe for displaying the postive feedback
df_new1=df_feedback.drop(["Longer time to get logged in (promotion, sales period)","Longer time in displaying graphics and photos (promotion, sales period)","Late declaration of price (promotion, sales period)",
                         "Longer page loading time (promotion, sales period)","Limited mode of payment on most products (promotion, sales period)","Longer delivery period",
                         "Frequent disruption when moving from one page to another",],axis=1)
df_new1
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
# A separate dataframe for displaying negative dataframe
df_new2 = df_feedback[["Longer time to get logged in (promotion, sales period)",
                       "Longer time in displaying graphics and photos (promotion, sales period)",
                       "Late declaration of price (promotion, sales period)",
                         "Longer page loading time (promotion, sales period)",
                       "Limited mode of payment on most products (promotion, sales period)",
                       "Longer delivery period",
                         "Frequent disruption when moving from one page to another"]]
df_new2
# Out:
#     Longer time to get logged in (promotion, sales period)  \
# 0                                            Amazon.in
# 1                              Amazon.in, Flipkart.com
# 2                                           Myntra.com
# 3                                         Snapdeal.com
# 4                              Flipkart.com, Paytm.com
# ..                                                 ...
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer time in displaying graphics and photos (promotion, sales period)  \
# 0                                            Amazon.in
# 1                                           Myntra.com
# 2                                           Myntra.com
# ...

# %%
#Analysing the negative feedback separately
website_list = ['Amazon.in','Flipkart.com','Snapdeal.com','Myntra.com','Paytm.com']# website list
col_names=[]  # Empty list for columns names
websites=[]   # Empty list for websites
count=[]      # Empty list for checking the number of counts for websites for mentioned
for i in df_new2.columns:
    for j in website_list:
        present=len(df_new2[df_new2[i].str.contains(j)]) #len(dfnew2[dfnew2[i].str.contains(j)])
        col_names.append(i)   #Appending the columns names
        websites.append(j)    # Appending the websites names
        count.append(present) # Appending the count of website present in the feedback

# %%
#creating the data frame for the negative feedback
negative_df = pd.DataFrame([col_names,websites,count])
negative_df
# Out:
#                                                   0   \
# 0  Longer time to get logged in (promotion, sales...
# 1                                          Amazon.in
# 2                                                135
#
#                                                   1   \
# 0  Longer time to get logged in (promotion, sales...
# 1                                       Flipkart.com
# 2                                                103
#
#                                                   2   \
# 0  Longer time to get logged in (promotion, sales...
# 1                                       Snapdeal.com
# 2                                                 67
#
#                                                   3   \
# 0  Longer time to get logged in (promotion, sales...
# 1                                         Myntra.com
# 2                                                 35
#
#                                                   4   \
# ...

# %%
#Transposting the dataframe to see clearly
negative_df=negative_df.transpose()
negative_df
# Out:
#                                                     0             1    2
# 0   Longer time to get logged in (promotion, sales...     Amazon.in  135
# 1   Longer time to get logged in (promotion, sales...  Flipkart.com  103
# 2   Longer time to get logged in (promotion, sales...  Snapdeal.com   67
# 3   Longer time to get logged in (promotion, sales...    Myntra.com   35
# 4   Longer time to get logged in (promotion, sales...     Paytm.com   77
# 5   Longer time in displaying graphics and photos ...     Amazon.in  126
# 6   Longer time in displaying graphics and photos ...  Flipkart.com   94
# 7   Longer time in displaying graphics and photos ...  Snapdeal.com   92
# 8   Longer time in displaying graphics and photos ...    Myntra.com   74
# 9   Longer time in displaying graphics and photos ...     Paytm.com   28
# 10  Late declaration of price (promotion, sales pe...     Amazon.in   56
# 11  Late declaration of price (promotion, sales pe...  Flipkart.com   43
# ...

# %%
#Replacing the index value for columns with feature names
negative_df.rename(columns={0:'Particulars',1:'Website',2:'People_Count'},inplace=True)
negative_df  #Checking the dataframe after replacing the column names
# Out:
#                                           Particulars       Website  \
# 0   Longer time to get logged in (promotion, sales...     Amazon.in
# 1   Longer time to get logged in (promotion, sales...  Flipkart.com
# 2   Longer time to get logged in (promotion, sales...  Snapdeal.com
# 3   Longer time to get logged in (promotion, sales...    Myntra.com
# 4   Longer time to get logged in (promotion, sales...     Paytm.com
# 5   Longer time in displaying graphics and photos ...     Amazon.in
# 6   Longer time in displaying graphics and photos ...  Flipkart.com
# 7   Longer time in displaying graphics and photos ...  Snapdeal.com
# 8   Longer time in displaying graphics and photos ...    Myntra.com
# 9   Longer time in displaying graphics and photos ...     Paytm.com
# 10  Late declaration of price (promotion, sales pe...     Amazon.in
# 11  Late declaration of price (promotion, sales pe...  Flipkart.com
# 12  Late declaration of price (promotion, sales pe...  Snapdeal.com
# ...

# %%
#Plotting barplot for people_count vs website relationship
sns.barplot(x='Website',y='People_Count',data=negative_df)
# Out:
# <AxesSubplot:xlabel='Website', ylabel='People_Count'>

# %% [markdown]
# -> During the promotion time, Amazon has received more negative feedback from customers followed by Snapdeal, Flipkart and Paytm.
#
# -> We can note that difference between negative feedbacks of the websites is not very huge and it needs to be improved in order to handle such situations

# %%
#Taking the list of numbers
import numpy as np
b=np.array(range(1,17))
b=b*5
b
# Out:
# array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80])

# %%
#Extracting feature wise comparison from negative feedback
try:
    for i in b:
        a=negative_df.iloc[i:i+5,:]
        sns.barplot(x='Website',y='People_Count',data=a)
        plt.title(a['Particulars'][i])
        plt.show()
        print("\n")
except ValueError: #As the value has some error while iterating,we are passing it by using except
    pass

# %% [markdown]
# Observations
#
# 1.Amazon takes longer time to get logged in during promotion, followed by flipkart, paytm and snapdeal.
#
# 2.Amazon takes longer time in displaying graphics and photos followed by flipkart and snapdeal.com.
#
# 3.Myntra and Paytm makes late declaration of price during promotion.
#
# 4.Paytm takes longer time to load the page during promotion.
#
# 5.Snapdeal and Amazon have limited mode of payment on most of products during promotion.
#
# 6.Paytm and Snapdeal take a longer delivery period, whereas Myntra and Amazon takes lesser delivery period.
#
# 7.Amazon, Snapdeal and Myntra have frequent discrepencies, when moving from one page to another

# %%
#Analysing the  postive feedback separately
website_list = ['Amazon.in','Flipkart.com','Snapdeal.com','Myntra.com','Paytm.com']# website list
col_names=[] #Empty list for col_names
websites=[]  #Empty list for websites
count=[]     #Empty list for checking the count of number of times the websites are mentioned 
for i in df_new1.columns:
    for j in website_list:
        present=len(df_new1[df_new1[i].str.contains(j)])
        col_names.append(i)#appending col_names
        websites.append(j)# appending websites names
        count.append(present)# appending count of website present in feedback

# %%
#Creating positive feedback dataframe
postive_df=pd.DataFrame([col_names,websites,count])
postive_df
# Out:
#                                                   0   \
# 0  From the following, tick any (or all) of the o...
# 1                                          Amazon.in
# 2                                                269
#
#                                                   1   \
# 0  From the following, tick any (or all) of the o...
# 1                                       Flipkart.com
# 2                                                221
#
#                                                   2   \
# 0  From the following, tick any (or all) of the o...
# 1                                       Snapdeal.com
# 2                                                182
#
#                                                   3   \
# 0  From the following, tick any (or all) of the o...
# 1                                         Myntra.com
# 2                                                146
#
#                                                   4   \
# ...

# %%
postive_df=postive_df.transpose()
postive_df
# Out:
#                                                     0             1    2
# 0   From the following, tick any (or all) of the o...     Amazon.in  269
# 1   From the following, tick any (or all) of the o...  Flipkart.com  221
# 2   From the following, tick any (or all) of the o...  Snapdeal.com  182
# 3   From the following, tick any (or all) of the o...    Myntra.com  146
# 4   From the following, tick any (or all) of the o...     Paytm.com  150
# ..                                                ...           ...  ...
# 80  Which of the Indian online retailer would you ...     Amazon.in  219
# 81  Which of the Indian online retailer would you ...  Flipkart.com  127
# 82  Which of the Indian online retailer would you ...  Snapdeal.com    0
# 83  Which of the Indian online retailer would you ...    Myntra.com   76
# 84  Which of the Indian online retailer would you ...     Paytm.com   44
#
# [85 rows x 3 columns]

# %%
postive_df.rename(columns={0:'Particulars',1:'Website',2:'People_count'},inplace=True)
postive_df
# Out:
#                                           Particulars       Website  \
# 0   From the following, tick any (or all) of the o...     Amazon.in
# 1   From the following, tick any (or all) of the o...  Flipkart.com
# 2   From the following, tick any (or all) of the o...  Snapdeal.com
# 3   From the following, tick any (or all) of the o...    Myntra.com
# 4   From the following, tick any (or all) of the o...     Paytm.com
# ..                                                ...           ...
# 80  Which of the Indian online retailer would you ...     Amazon.in
# 81  Which of the Indian online retailer would you ...  Flipkart.com
# 82  Which of the Indian online retailer would you ...  Snapdeal.com
# 83  Which of the Indian online retailer would you ...    Myntra.com
# 84  Which of the Indian online retailer would you ...     Paytm.com
#
#    People_count
# 0           269
# 1           221
# 2           182
# 3           146
# 4           150
# ..          ...
# 80          219
# ...

# %%
#importing matplotlib and seaborn libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#plotting barplot for website  vs people_count releationship
sns.barplot(x='Website',y='People_count',data=postive_df)
# Out:
# <AxesSubplot:xlabel='Website', ylabel='People_count'>

# %%
b=np.array(range(17))
b=b*5
b=list(b)
b
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %%
#Extracting feature wise comparison from positive feedback dataframe and plotting the data using pie chart
for i in b:
    a=postive_df.iloc[i:i+5,:]
    plt.pie('People_count',labels='Website',data=a)
    plt.title(a['Particulars'][i])
    plt.show()
    print("\n")

# %%
#Extracting feature wise comparison from positive feedback dataframe and plotting bar plot
for i in b:
    a=postive_df.iloc[i:i+5,:]
    sns.barplot(x='Website',y='People_count',data=a)
    plt.title(a['Particulars'][i])
    plt.show()
    print("\n")

# %% [markdown]
# Observations
# 1.Many customers have shopped from Amazon and Flipkart.
#
# 2.Amazon and Flipkart have been named most as easy to use website
#
# 3.Amazon and Flipkart have been named as the most visually appealing web page layout and also having wild variety of products.
#
# 4.Paytm and Snapdeal had not been given more marks on availability of wild variety of products.
#
# 5.Amazon and Flipkart have got more positive feedbacks than other websites with relevant to Complete, relevant description information of products, Fast loading of websites, Reliability of website, quickness to complete purchase, availability of several payment options, speedy order delivery, privacy of customers information, security of customer financial information, etc.
#
# 6.Paytm has got less feedbacks in perceived trustworthiness, presence of online assistance through multi-channel, speed order delivery.
#
# 7.Snapdeal.com has got less number of feedbacks in change of website/application design.
#
# 8.Myntra has got the least feedbacks in website as efficient as before, followed by Snapdeal.
#
# 9.Only one person has recommended Snapdeal.com overall.

# %% [markdown]
# # Calculating the percentage wise feedback analysis

# %% [markdown]
# Now, we will calculate the percentage of people giving the feedbacks to the website for both positive and negative data

# %%
postive_df
# Out:
#                                           Particulars       Website  \
# 0   From the following, tick any (or all) of the o...     Amazon.in
# 1   From the following, tick any (or all) of the o...  Flipkart.com
# 2   From the following, tick any (or all) of the o...  Snapdeal.com
# 3   From the following, tick any (or all) of the o...    Myntra.com
# 4   From the following, tick any (or all) of the o...     Paytm.com
# ..                                                ...           ...
# 80  Which of the Indian online retailer would you ...     Amazon.in
# 81  Which of the Indian online retailer would you ...  Flipkart.com
# 82  Which of the Indian online retailer would you ...  Snapdeal.com
# 83  Which of the Indian online retailer would you ...    Myntra.com
# 84  Which of the Indian online retailer would you ...     Paytm.com
#
#    People_count
# 0           269
# 1           221
# 2           182
# 3           146
# 4           150
# ..          ...
# 80          219
# ...

# %%
#Adding a new column to the dataframe
postive_df['% user feedbacks']=0
postive_df.sort_values(by='Website',inplace=True)
postive_df.reset_index()
# Out:
#     index                                        Particulars       Website  \
# 0       0  From the following, tick any (or all) of the o...     Amazon.in
# 1      50                  Privacy of customers’ information     Amazon.in
# 2      60                          Perceived Trustworthiness     Amazon.in
# 3      45                             Speedy order delivery      Amazon.in
# 4      40            Availability of several payment options     Amazon.in
# ..    ...                                                ...           ...
# 80     62                          Perceived Trustworthiness  Snapdeal.com
# 81     47                             Speedy order delivery   Snapdeal.com
# 82     52                  Privacy of customers’ information  Snapdeal.com
# 83     72               Change in website/Application design  Snapdeal.com
# 84     42            Availability of several payment options  Snapdeal.com
#
#    People_count  % user feedbacks
# ...

# %%
#Index range values of all website with Maximum users value
#positive_df.iloc[0:17]   #Amazon data range and maximum users are 269 
#positive_df.iloc[17:34]  #Flipkart data range and maximum users are 221
#positive_df.iloc[34:51]  #Myntra data range and maximum users are 147
#positive_df.iloc[51:68]  #Paytm data range and maximum users are 150
#positive_df.iloc[68:85]  #Snapdeal data range and maximum users are 182

# %%
#Calculating the percentage for all data
postive_df['% user feedbacks'].iloc[0:17]=(postive_df['People_count'].iloc[0:17]*100)/269 # Amazon users
postive_df['% user feedbacks'].iloc[17:34]=(postive_df['People_count'].iloc[17:34]*100)/221 # Flipkart users
postive_df['% user feedbacks'].iloc[34:51]=(postive_df['People_count'].iloc[34:51]*100)/147 # Myntra users
postive_df['% user feedbacks'].iloc[51:68]=(postive_df['People_count'].iloc[51:68]*100)/150 # Paytm users
postive_df['% user feedbacks'].iloc[68:85]=(postive_df['People_count'].iloc[68:85]*100)/182 # Snapdeal users

# %%
postive_df
# Out:
#                                           Particulars       Website  \
# 0   From the following, tick any (or all) of the o...     Amazon.in
# 50                  Privacy of customers’ information     Amazon.in
# 60                          Perceived Trustworthiness     Amazon.in
# 45                             Speedy order delivery      Amazon.in
# 40            Availability of several payment options     Amazon.in
# ..                                                ...           ...
# 62                          Perceived Trustworthiness  Snapdeal.com
# 47                             Speedy order delivery   Snapdeal.com
# 52                  Privacy of customers’ information  Snapdeal.com
# 72               Change in website/Application design  Snapdeal.com
# 42            Availability of several payment options  Snapdeal.com
#
#    People_count % user feedbacks
# 0           269            100.0
# 50          221        82.156134
# 60          227        84.386617
# ...

# %%
#Sorting values in Descending order
new_postive=postive_df.sort_values(by=['% user feedbacks'],ascending=False)
new_postive
# Out:
#                                           Particulars       Website  \
# 0   From the following, tick any (or all) of the o...     Amazon.in
# 4   From the following, tick any (or all) of the o...     Paytm.com
# 2   From the following, tick any (or all) of the o...  Snapdeal.com
# 1   From the following, tick any (or all) of the o...  Flipkart.com
# 8                  Easy to use website or application    Myntra.com
# ..                                                ...           ...
# 37                     Quickness to complete purchase  Snapdeal.com
# 67  Presence of online assistance through multi-ch...  Snapdeal.com
# 49                             Speedy order delivery      Paytm.com
# 82  Which of the Indian online retailer would you ...  Snapdeal.com
# 35                     Quickness to complete purchase     Amazon.in
#
#    People_count % user feedbacks
# 0           269            100.0
# 4           150            100.0
# 2           182            100.0
# ...

# %%
new_postive[0:20]   #Checking the percentages for some rows
# Out:
#                                           Particulars       Website  \
# 0   From the following, tick any (or all) of the o...     Amazon.in
# 4   From the following, tick any (or all) of the o...     Paytm.com
# 2   From the following, tick any (or all) of the o...  Snapdeal.com
# 1   From the following, tick any (or all) of the o...  Flipkart.com
# 8                  Easy to use website or application    Myntra.com
# 3   From the following, tick any (or all) of the o...    Myntra.com
# 5                  Easy to use website or application     Amazon.in
# 25  Fast loading website speed of website and appl...     Amazon.in
# 41            Availability of several payment options  Flipkart.com
# 6                  Easy to use website or application  Flipkart.com
# 43            Availability of several payment options    Myntra.com
# 45                             Speedy order delivery      Amazon.in
# 20  Complete, relevant description information of ...     Amazon.in
# ...

# %%
new_postive[20:40]   #Checking the percentages for some rows
# Out:
#                                           Particulars       Website  \
# 50                  Privacy of customers’ information     Amazon.in
# 15                   Wild variety of product on offer     Amazon.in
# 80  Which of the Indian online retailer would you ...     Amazon.in
# 40            Availability of several payment options     Amazon.in
# 11                   Visual appealing web-page layout  Flipkart.com
# 13                   Visual appealing web-page layout    Myntra.com
# 55         Security of customer financial information     Amazon.in
# 68  Presence of online assistance through multi-ch...    Myntra.com
# 26  Fast loading website speed of website and appl...  Flipkart.com
# 46                             Speedy order delivery   Flipkart.com
# 36                     Quickness to complete purchase  Flipkart.com
# 7                  Easy to use website or application  Snapdeal.com
# 39                     Quickness to complete purchase     Paytm.com
# ...

# %%
new_postive[40:60]   #Checking the percentages for some rows
# Out:
#                                           Particulars       Website  \
# 58         Security of customer financial information    Myntra.com
# 66  Presence of online assistance through multi-ch...  Flipkart.com
# 63                          Perceived Trustworthiness    Myntra.com
# 59         Security of customer financial information     Paytm.com
# 81  Which of the Indian online retailer would you ...  Flipkart.com
# 57         Security of customer financial information  Snapdeal.com
# 38                     Quickness to complete purchase    Myntra.com
# 53                  Privacy of customers’ information    Myntra.com
# 76                  Website is as efficient as before  Flipkart.com
# 70               Change in website/Application design     Amazon.in
# 83  Which of the Indian online retailer would you ...    Myntra.com
# 28  Fast loading website speed of website and appl...    Myntra.com
# 42            Availability of several payment options  Snapdeal.com
# ...

# %%
new_postive[60:85]   #Checking the percentages for some rows
# Out:
#                                           Particulars       Website  \
# 62                          Perceived Trustworthiness  Snapdeal.com
# 24  Complete, relevant description information of ...     Paytm.com
# 79                  Website is as efficient as before     Paytm.com
# 12                   Visual appealing web-page layout  Snapdeal.com
# 71               Change in website/Application design  Flipkart.com
# 22  Complete, relevant description information of ...  Snapdeal.com
# 84  Which of the Indian online retailer would you ...     Paytm.com
# 47                             Speedy order delivery   Snapdeal.com
# 73               Change in website/Application design    Myntra.com
# 52                  Privacy of customers’ information  Snapdeal.com
# 32          Reliability of the website or application  Snapdeal.com
# 48                             Speedy order delivery     Myntra.com
# 69  Presence of online assistance through multi-ch...     Paytm.com
# ...

# %% [markdown]
# Observations from positive feedback:
#
# 1.Amazon and Flipkart ranks about 90% in satisfying customers, followed by myntra.
#
# 2.The maximum percentage paytm and snapdeal could score here is 83 and 71 respectively.
#
# 3.No one is willing to refer snapdeal to their contacts as it has the less percentage among all websites.
#
# 4.On an average, snapdeal and paytm scores are less when compared to amazon, flipkart and myntra.

# %%
negative_df
# Out:
#                                           Particulars       Website  \
# 0   Longer time to get logged in (promotion, sales...     Amazon.in
# 1   Longer time to get logged in (promotion, sales...  Flipkart.com
# 2   Longer time to get logged in (promotion, sales...  Snapdeal.com
# 3   Longer time to get logged in (promotion, sales...    Myntra.com
# 4   Longer time to get logged in (promotion, sales...     Paytm.com
# 5   Longer time in displaying graphics and photos ...     Amazon.in
# 6   Longer time in displaying graphics and photos ...  Flipkart.com
# 7   Longer time in displaying graphics and photos ...  Snapdeal.com
# 8   Longer time in displaying graphics and photos ...    Myntra.com
# 9   Longer time in displaying graphics and photos ...     Paytm.com
# 10  Late declaration of price (promotion, sales pe...     Amazon.in
# 11  Late declaration of price (promotion, sales pe...  Flipkart.com
# 12  Late declaration of price (promotion, sales pe...  Snapdeal.com
# ...

# %%
#As there are less number of negative feedbacks, we will calculate the people count percentage first
for i in range(0,35,5):
    negative_df['Percentage']=(negative_df['People_Count']*100)/(negative_df.iloc[i:i+5,2].sum())
    
negative_df
# Out:
#                                           Particulars       Website  \
# 0   Longer time to get logged in (promotion, sales...     Amazon.in
# 20  Limited mode of payment on most products (prom...     Amazon.in
# 15  Longer page loading time (promotion, sales per...     Amazon.in
# 30  Frequent disruption when moving from one page ...     Amazon.in
# 5   Longer time in displaying graphics and photos ...     Amazon.in
# 25                             Longer delivery period     Amazon.in
# 10  Late declaration of price (promotion, sales pe...     Amazon.in
# 16  Longer page loading time (promotion, sales per...  Flipkart.com
# 26                             Longer delivery period  Flipkart.com
# 21  Limited mode of payment on most products (prom...  Flipkart.com
# 11  Late declaration of price (promotion, sales pe...  Flipkart.com
# 6   Longer time in displaying graphics and photos ...  Flipkart.com
# 31  Frequent disruption when moving from one page ...  Flipkart.com
# ...

# %%
#We will now calculate the percentage of feedbacks in terms of websites
negative_df['% user feedbacks']=0
negative_df.sort_values(by='Website',inplace=True)
negative_df.reset_index()
# Out:
#     index                                        Particulars       Website  \
# 0       0  Longer time to get logged in (promotion, sales...     Amazon.in
# 1      20  Limited mode of payment on most products (prom...     Amazon.in
# 2      15  Longer page loading time (promotion, sales per...     Amazon.in
# 3      30  Frequent disruption when moving from one page ...     Amazon.in
# 4       5  Longer time in displaying graphics and photos ...     Amazon.in
# 5      25                             Longer delivery period     Amazon.in
# 6      10  Late declaration of price (promotion, sales pe...     Amazon.in
# 7       1  Longer time to get logged in (promotion, sales...  Flipkart.com
# 8      31  Frequent disruption when moving from one page ...  Flipkart.com
# 9       6  Longer time in displaying graphics and photos ...  Flipkart.com
# 10     26                             Longer delivery period  Flipkart.com
# ...

# %%
#Index range values of all website with Maximum users value
#negative_df.iloc[0:7]   #Amazon data range and maximum users are 269 
#negative_df.iloc[7:14]  #Flipkart data range and maximum users are 221
#negative_df.iloc[14:21]  #Myntra data range and maximum users are 147
#negative_df.iloc[21:28]  #Paytm data range and maximum users are 150
#negative_df.iloc[28:35]  #Snapdeal data range and maximum users are 182

# %%
#Calculating the percentage for all data
negative_df['% user feedbacks'].iloc[0:7]=(negative_df['People_Count'].iloc[0:7]*100)/269 # Amazon users
negative_df['% user feedbacks'].iloc[7:14]=(negative_df['People_Count'].iloc[7:14]*100)/221 # Flipkart users
negative_df['% user feedbacks'].iloc[14:21]=(negative_df['People_Count'].iloc[14:21]*100)/147 # Myntra users
negative_df['% user feedbacks'].iloc[21:28]=(negative_df['People_Count'].iloc[21:28]*100)/150 # Paytm users
negative_df['% user feedbacks'].iloc[28:35]=(negative_df['People_Count'].iloc[28:35]*100)/182 # Snapdeal users

# %%
negative_df
# Out:
#                                           Particulars       Website  \
# 0   Longer time to get logged in (promotion, sales...     Amazon.in
# 20  Limited mode of payment on most products (prom...     Amazon.in
# 15  Longer page loading time (promotion, sales per...     Amazon.in
# 30  Frequent disruption when moving from one page ...     Amazon.in
# 5   Longer time in displaying graphics and photos ...     Amazon.in
# 25                             Longer delivery period     Amazon.in
# 10  Late declaration of price (promotion, sales pe...     Amazon.in
# 16  Longer page loading time (promotion, sales per...  Flipkart.com
# 26                             Longer delivery period  Flipkart.com
# 21  Limited mode of payment on most products (prom...  Flipkart.com
# 11  Late declaration of price (promotion, sales pe...  Flipkart.com
# 6   Longer time in displaying graphics and photos ...  Flipkart.com
# 31  Frequent disruption when moving from one page ...  Flipkart.com
# ...

# %%
negative_df.sort_values(by=['% user feedbacks','Website'],ascending=False)
# Out:
#                                           Particulars       Website  \
# 29                             Longer delivery period     Paytm.com
# 19  Longer page loading time (promotion, sales per...     Paytm.com
# 22  Limited mode of payment on most products (prom...  Snapdeal.com
# 4   Longer time to get logged in (promotion, sales...     Paytm.com
# 13  Late declaration of price (promotion, sales pe...    Myntra.com
# 7   Longer time in displaying graphics and photos ...  Snapdeal.com
# 8   Longer time in displaying graphics and photos ...    Myntra.com
# 0   Longer time to get logged in (promotion, sales...     Amazon.in
# 27                             Longer delivery period  Snapdeal.com
# 14  Late declaration of price (promotion, sales pe...     Paytm.com
# 5   Longer time in displaying graphics and photos ...     Amazon.in
# 1   Longer time to get logged in (promotion, sales...  Flipkart.com
# 18  Longer page loading time (promotion, sales per...    Myntra.com
# ...

# %% [markdown]
# Observations
#
# 1.Around 65% of paytm customers are not happy with their delivery period and longer term in loading pages.
#
# 2.Approx 60% of snapdeal customers are not happy about their limited mode of payment and nearly 50% of people are not satisfied in longer time of displaying graphics.
#
# 3.We can observe that even though with count wise, Amazon and Flipkart showed more negative reviews. When we take percentage, in top 10, Amazon has appeared only once and flipkart has not even appeared even one time.
#
# 4.The highest percentage myntra got is 51, where as flipkart's highest percentage is 46. However, other websites like paytm, snapdeal.com have got highest percentage for negative reviews around 60-67%.
#
# 5.In terms of less dissatisfaction, myntra.com and flipkart are better, followed by amazon.
